# %% [markdown]
# <p><img alt="Naas logo" height="45px" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160" align="left" hspace="10px" vspace="0px"></p>
# <br>
# <br>
# <h1>What is Naas?</h1>
#
# Naas, or 'Notebooks as a service' in long, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to a private server with 4Go RAM, 1 vCPU Processor and 20Go storage.
# - Easy scheduling and sharing.
#
# Whether you're a <strong>student</strong>, a <strong>data professional</strong>, an <strong>AI wizard</strong> or a <strong>business owner</strong>, Naas can make your work easier.<br>

# %% [markdown]
# # <strong>🚀 Getting started</strong>
#
# The document that you are reading is not a static web page, but an interactive environment called a <strong>Naas notebook</strong> that lets you write and execute code.
#
# For example, here is a <strong>code cell</strong> with a short Python script that computes a value, stores it in a variable and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut 'Command/Ctrl+Enter'. <br>To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Naas notebooks allow you to combine <strong>executable code</strong> and <strong>rich text</strong> in a single document, along with <strong>images</strong>, <strong>HTML</strong>, and more.<br>When you create your own Naas notebooks, they are stored in your a private 20Go storage unit.<br>You can easily share your Naas notebooks with co-workers or friends, with a single sharing link. To find out more, see <a href="https://naas.gitbook.io/naas/features">our online documentation</a>.<br>To create a new Naas notebook you can use the menu above following the path: **File > New > Notebook.**
#
# Naas notebooks are Jupyter notebooks with added microservices that are hosted by CASHSTORY SAS. To find out more about the Jupyter project, see <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# ## Data science
#
# With Naas you can harness the full power of popular Python libraries with low-code formulas to analyse and visualise data.<br> The code cell below uses <strong>naas_drivers</strong> to generate a table from <strong>Yahoo Finance</strong>, and uses <strong>Plotly</strong> to visualise it. <br>To edit the code, just click the cell and start editing.

# %%
import naas_drivers
stock_name = 'NFLX'  
table = naas_drivers.yahoofinance.get(stock_name, date_from=-3600, date_to="today", moving_averages=[20,50])
table
# Out:
# getted data for NFLX https://query1.finance.yahoo.com/v7/finance/download/NFLX?period1=1315417259&period2=1626457259&interval=1d&events=history
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2011-09-07   31.641430   31.711430   30.367144   30.857143   30.857143
# 1    2011-09-08   30.580000   31.250000   29.972857   30.171429   30.171429
# 2    2011-09-09   30.031429   30.299999   29.027143   29.138571   29.138571
# 3    2011-09-12   28.758572   30.090000   28.374287   30.007143   30.007143
# 4    2011-09-13   29.994286   29.997143   29.150000   29.821428   29.821428
# ...         ...         ...         ...         ...         ...         ...
# 2476 2021-07-12  540.299988  540.650024  532.919983  537.309998  537.309998
# 2477 2021-07-13  535.760010  545.330017  535.760010  540.679993  540.679993
# 2478 2021-07-14  541.010010  554.099976  541.010010  547.950012  547.950012
# ...

# %%
chart = naas_drivers.plotly.linechart(table, label_x="Date", label_y=["Close"])
chart

# %% [markdown]
# You can access all your tools with Naas notebooks, including Google spreadsheets, as well as from GitHub and many other open-data sources.<br>To find out more about accessing data, and how Naas can be used for data science, chat with us in our community Slack <a href="https://aiclub-hq.slack.com/">The AI Club</a> (AI for automated intelligence 😉)

# %% [markdown]
# <h2>Machine learning</h2>
#
# With Naas you can import an image dataset, train an image classifier, play with a transformer, and evaluate the model, all in just a few lines of code.</a><br>Naas notebooks execute code on AWS cloud servers, meaning you can leverage the power of the only provider that ensure 99.99% uptime.<br> We provide <a href="https://calendly.com/jeremyravenel"> GPUs and TPUs</a> ,on demand. All you need is a browser.
#
# With Naas your can used machine learning on applications where it's necessary to make:
# - Sentiment analysis
# - Linear regression and classification
# - Video to text
# - Transformers for NLP
# - Creating tutorials and summarizing text
#
# Always ask yourself the question : is machine learning really necessary ?
# Sometime, a good old regex do the trick.
#
# To see sample Naas notebooks that demonstrate machine learning applications, ask for private demos of <a href="https://calendly.com/jeremyravenel">machine learning examples</a>.

# %% [markdown]
# ## Schedule your first notebook
#
# Jupyter-Naas is an opensource project that provides scheduling and other micro-services, drivers and notebooks templates to the original version of JupyterLab.<br>JupyterLab is a web-based interactive development environment for Jupyter notebooks, code, and data. <br>
# JupyterLab is flexible: users can configure and arrange the user interface to support a wide range of workflows in data science, scientific computing, and machine learning.
#
#
# 📺 Click on the image below to start learning how to schedule your Naas notebook on our <a href="https://www.youtube.com/channel/UCKKG5hzjXXU_rRdHHWQ8JHQ?sub_confirmation=1">Youtube channel</a>.<br>
# Subscribe and follow us, we normally upload 2 videos a week.
#
# [![IMAGE ALT TEXT](http://img.youtube.com/vi/ONiILHFItzs/0.jpg)](http://www.youtube.com/watch?v=ONiILHFItzs?sub_confirmation=1 "Scheduling notebooks")

# %% [markdown]
# ## Other features
# Jupyter-Naas other microservices list includes the following :
# * Webhook
# * Asset sharing
# * Notifications
# * Secret keys
# * Callbacks
# * Domain exposure
#
# 📚 Documentation : https://docs.naas.ai/ <br>
# 🐍 Naas Python packages:  https://pypi.org/project/naas/ <br>
# ⭐️ Opensource roadmap: https://github.com/orgs/jupyter-naas/projects/4 <br>
#
# Jupyter-Naas is hosted on CASHSTORY SAS servers (AWS-West-Europe) and distributed under the domain name : www.naas.ai - All rights reserved

# %% [markdown]
# ## 🥊  Templates
# +100 awesome Jupyter Notebooks templates, organized by tools, published by the Naas community, to kickstart your data projects in minutes. 😎<br>
#
# This project is made for tech-savvy users that wants to save time building their data projects.
#
# Benefit from the open-source collective intelligence and get access to a list of awesome Jupyter Notebooks<br>
# 👉 <a href="https://github.com/jupyter-naas/awesome-notebooks">Access the template list</a>
#
# *PS: If you contribute to this library of open-source notebooks templates, you can X2 your monthly credits 🏆*

# %% [markdown]
# ## More resources
#
# Naas is the first Jupyter based data-science platform that allows you to schedule, run, and expose all the awesome things you can with notebooks.
# SaaS & Open-source.
#
# - Github open-source repository:
# https://github.com/jupyter-naas
#
# -  Credit-based system information:
# https://www.naas.ai/pricing
#
# -  Access to the Slack Community:
# https://app.slack.com/client/T01E5188RNV
#
#
# Follow us on social medias :
#
# [Youtube](https://www.youtube.com/channel/UCKKG5hzjXXU_rRdHHWQ8JHQ?sub_confirmation=1) | [LinkedIn](https://www.linkedin.com/showcase/naas) | [Twitter](https://twitter.com/JupyterNaas)
